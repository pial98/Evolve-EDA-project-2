# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# !pip install cartopy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (2.3.5)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from seaborn) (2.3.5)
# Requirement already satisfied: pandas>=1.2 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from seaborn) (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: cartopy in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (0.25.0)
# Requirement already satisfied: numpy>=1.23 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from cartopy) (2.3.5)
# Requirement already satisfied: matplotlib>=3.6 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from cartopy) (3.10.7)
# Requirement already satisfied: shapely>=2.0 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from cartopy) (2.1.2)
# Requirement already satisfied: packaging>=21 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from cartopy) (25.0)
# Requirement already satisfied: pyshp>=2.3 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from cartopy) (3.0.3)
# Requirement already satisfied: pyproj>=3.3.1 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from cartopy) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from matplotlib>=3.6->cartopy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from matplotlib>=3.6->cartopy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from matplotlib>=3.6->cartopy) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from matplotlib>=3.6->cartopy) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from matplotlib>=3.6->cartopy) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from matplotlib>=3.6->cartopy) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from matplotlib>=3.6->cartopy) (2.9.0.post0)
# Requirement already satisfied: certifi in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from pyproj>=3.3.1->cartopy) (2025.11.12)
# Requirement already satisfied: six>=1.5 in c:\users\elcorteingles\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.7->matplotlib>=3.6->cartopy) (1.17.0)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd

plt.style.use("ggplot")

# %% [markdown]
# # Carga del Dataset 3.1

# %%
path = "../data/dataset.csv"
df = pd.read_csv(path)
df.head()
# Out:
#            userid                                  placeid  \
# 0         katinka              rushcutters-bay-park-sydney
# 1  stephanie-moss  gallery-at-chastain-arts-center-atlanta
# 2   chris-abraham             golds-gym-ballston-arlington
# 3  michael-sippey                                      NaN
# 4      bob-aycock            americana-restaurant-matthews
#
#               datetime        lat         lon       city  \
# 0  2010-03-29T08:24:58 -33.874798  151.230111     Sydney
# 1  2009-12-30T17:26:39  33.875992  -84.391470    Atlanta
# 2  2010-06-06T00:16:43  38.879700  -77.106600  Arlington
# 3  2010-09-29T15:27:03        NaN -122.254613        NaN
# 4  2010-11-11T23:30:56  35.119343  -80.695147   Matthews
#
#                            category
# 0             Parks & Outdoors:Park
# 1  Arts & Entertainment:Art Gallery
# 2                               NaN
# 3                  Food:Coffee Shop
# 4                               NaN

# %%
print("Shape" , df.shape) #For rows and columns
# Out:
# Shape (956323, 7)

# %%
df.columns #All the names of the columns in the dataset.
# Out:
# Index(['userid', 'placeid', 'datetime', 'lat', 'lon', 'city', 'category'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 956323 entries, 0 to 956322
# Data columns (total 7 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   userid    937212 non-null  object
#  1   placeid   889431 non-null  object
#  2   datetime  774996 non-null  object
#  3   lat       832149 non-null  float64
#  4   lon       879675 non-null  float64
#  5   city      745946 non-null  object
#  6   category  592896 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 51.1+ MB

# %%
df.describe()
# Out:
#                  lat            lon
# count  832149.000000  879675.000000
# mean       37.806054     -69.539445
# std        14.290973      58.978632
# min       -79.820243    -168.750000
# 25%        37.373490    -117.169303
# 50%        40.677242     -77.041663
# 75%        42.326015     -73.692822
# max        70.198084     177.985690

# %% [markdown]
# # Exploración del dataset 3.2

# %% [markdown]
# #### Valores nulos

# %%
df.isnull()
# Out:
#         userid  placeid  datetime    lat    lon   city  category
# 0        False    False     False  False  False  False     False
# 1        False    False     False  False  False  False     False
# 2        False    False     False  False  False  False      True
# 3        False     True     False   True  False   True     False
# 4        False    False     False  False  False  False      True
# ...        ...      ...       ...    ...    ...    ...       ...
# 956318   False    False      True  False  False  False     False
# 956319   False    False     False  False  False  False     False
# 956320   False    False     False  False  False   True      True
# 956321   False    False     False  False  False   True      True
# 956322   False    False     False  False  False  False      True
#
# [956323 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# userid       19111
# placeid      66892
# datetime    181327
# lat         124174
# lon          76648
# city        210377
# category    363427
# dtype: int64

# %%
null_pct=(df.isnull().mean())*100
print(null_pct)
# Out:
# userid       1.998383
# placeid      6.994708
# datetime    18.960853
# lat         12.984525
# lon          8.014865
# city        21.998530
# category    38.002537
# dtype: float64

# %% [markdown]
# #### Valores duplicados

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 956318    False
# 956319    False
# 956320    False
# 956321    False
# 956322    False
# Length: 956323, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(27784)

# %% [markdown]
# #### Valores unicos

# %%
df['userid'].nunique()
# Out:
# 2950

# %%
df['category'].nunique()
# Out:
# 693

# %%
df['lat'].nunique()
# Out:
# 160472

# %%
df['lon'].nunique()
# Out:
# 162812

# %%
df['placeid'].nunique()
# Out:
# 169378

# %%
df['datetime'].head()  #We need to extract date and time separately
# Out:
# 0    2010-03-29T08:24:58
# 1    2009-12-30T17:26:39
# 2    2010-06-06T00:16:43
# 3    2010-09-29T15:27:03
# 4    2010-11-11T23:30:56
# Name: datetime, dtype: object

# %%
df['city'].nunique()
# Out:
# 11732

# %% [markdown]
# # Rango de las variables

# %% [markdown]
# #### Numeric

# %%
Rnum=df.select_dtypes(include=[np.number]).columns.to_list() #only selects the numeric column
display(df[Rnum].describe().T)
for c in Rnum:
    print(c ,"min" , df[c].min() ,"," "max" , df[c].max())
# Out:
#         count       mean        std         min         25%        50%  \
# lat  832149.0  37.806054  14.290973  -79.820243   37.373490  40.677242
# lon  879675.0 -69.539445  58.978632 -168.750000 -117.169303 -77.041663
#
#            75%         max
# lat  42.326015   70.198084
# lon -73.692822  177.985690
# lat min -79.8202427478 ,max 70.1980836
# lon min -168.75 ,max 177.98569

# %% [markdown]
# #### Object

# %%
Robj=df.select_dtypes(include=['object']).columns.to_list()
display(df[Robj].describe().T)
# Out:
#            count  unique                                                top  \
# userid    937212    2950                                        thadd-fiala
# placeid   889431  169378  san-francisco-international-airport-sfo-san-fr...
# datetime  774996  765837                                2010-06-06T00:44:47
# city      745946   11732                                           New York
# category  592896     693             Home / Work / Other:Corporate / Office
#
#             freq
# userid      3794
# placeid     3290
# datetime       4
# city      116754
# category   35751

# %% [markdown]
# # 3.3 Limpeieza y Normalizacion

# %%
df_clean= df.copy()
df_clean.head()
# Out:
#            userid                                  placeid  \
# 0         katinka              rushcutters-bay-park-sydney
# 1  stephanie-moss  gallery-at-chastain-arts-center-atlanta
# 2   chris-abraham             golds-gym-ballston-arlington
# 3  michael-sippey                                      NaN
# 4      bob-aycock            americana-restaurant-matthews
#
#               datetime        lat         lon       city  \
# 0  2010-03-29T08:24:58 -33.874798  151.230111     Sydney
# 1  2009-12-30T17:26:39  33.875992  -84.391470    Atlanta
# 2  2010-06-06T00:16:43  38.879700  -77.106600  Arlington
# 3  2010-09-29T15:27:03        NaN -122.254613        NaN
# 4  2010-11-11T23:30:56  35.119343  -80.695147   Matthews
#
#                            category
# 0             Parks & Outdoors:Park
# 1  Arts & Entertainment:Art Gallery
# 2                               NaN
# 3                  Food:Coffee Shop
# 4                               NaN

# %% [markdown]
# #### datetime corrección

# %% [markdown]
# ##### Date correcion

# %%
df_clean['datetime']= pd.to_datetime(df_clean['datetime'] ,errors='coerce') #Converting datetime 
df_clean['datetime'].head()
# Out:
# 0   2010-03-29 08:24:58
# 1   2009-12-30 17:26:39
# 2   2010-06-06 00:16:43
# 3   2010-09-29 15:27:03
# 4   2010-11-11 23:30:56
# Name: datetime, dtype: datetime64[ns]

# %%
df_clean['datetime'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df_clean['datetime'].isna() #There are null values.
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 956318     True
# 956319    False
# 956320    False
# 956321    False
# 956322    False
# Name: datetime, Length: 956323, dtype: bool

# %%
df_clean['date']=df_clean['datetime'].dt.date
df_clean['time']=df_clean['datetime'].dt.time

# %%
df_clean.head()
# Out:
#            userid                                  placeid  \
# 0         katinka              rushcutters-bay-park-sydney
# 1  stephanie-moss  gallery-at-chastain-arts-center-atlanta
# 2   chris-abraham             golds-gym-ballston-arlington
# 3  michael-sippey                                      NaN
# 4      bob-aycock            americana-restaurant-matthews
#
#              datetime        lat         lon       city  \
# 0 2010-03-29 08:24:58 -33.874798  151.230111     Sydney
# 1 2009-12-30 17:26:39  33.875992  -84.391470    Atlanta
# 2 2010-06-06 00:16:43  38.879700  -77.106600  Arlington
# 3 2010-09-29 15:27:03        NaN -122.254613        NaN
# 4 2010-11-11 23:30:56  35.119343  -80.695147   Matthews
#
#                            category        date      time
# 0             Parks & Outdoors:Park  2010-03-29  08:24:58
# 1  Arts & Entertainment:Art Gallery  2009-12-30  17:26:39
# 2                               NaN  2010-06-06  00:16:43
# 3                  Food:Coffee Shop  2010-09-29  15:27:03
# 4                               NaN  2010-11-11  23:30:56

# %%
df_clean.drop(columns=['datetime'] , inplace=True) #Delete the datetime column

# %%
df_clean.head()
# Out:
#            userid                                  placeid        lat  \
# 0         katinka              rushcutters-bay-park-sydney -33.874798
# 1  stephanie-moss  gallery-at-chastain-arts-center-atlanta  33.875992
# 2   chris-abraham             golds-gym-ballston-arlington  38.879700
# 3  michael-sippey                                      NaN        NaN
# 4      bob-aycock            americana-restaurant-matthews  35.119343
#
#           lon       city                          category        date  \
# 0  151.230111     Sydney             Parks & Outdoors:Park  2010-03-29
# 1  -84.391470    Atlanta  Arts & Entertainment:Art Gallery  2009-12-30
# 2  -77.106600  Arlington                               NaN  2010-06-06
# 3 -122.254613        NaN                  Food:Coffee Shop  2010-09-29
# 4  -80.695147   Matthews                               NaN  2010-11-11
#
#        time
# 0  08:24:58
# 1  17:26:39
# 2  00:16:43
# 3  15:27:03
# 4  23:30:56

# %%
missing_date_pct=df_clean['date'].isna().sum()/len(df_clean)*100
print(missing_date_pct)
# Out:
# 18.960853184541207

# %%
df_clean['date'].isna().sum()
# Out:
# np.int64(181327)

# %%
df_clean['date']=df_clean.groupby('userid')['date'].ffill()  #imputing date values using forward filling because it is important for temporal relations.

# %%
df_clean['date'].isna().sum()
# Out:
# np.int64(19804)

# %%
missing_date_pct=df_clean['date'].isna().sum()/len(df_clean)*100
print(missing_date_pct)
# Out:
# 2.070848447647918

# %%
df_clean['date']=pd.to_datetime(df_clean['date']) #converting object type date to datetime format
df_clean['date'].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# #### Time correccion

# %%
df_clean['time'].isna().sum()
# Out:
# np.int64(181327)

# %%
missing_time_pct=df_clean['time'].isna().sum()/len(df_clean)*100
print(missing_time_pct)
# Out:
# 18.960853184541207

# %%
df_clean['time']=df_clean.groupby('userid')['time'].ffill()  #imputing date values using forward filling because it is important for temporal relations.

# %%
df_clean['time'].isna().sum()
# Out:
# np.int64(19804)

# %%
missing_time_pct=df_clean['time'].isna().sum()/len(df_clean)*100
print(missing_time_pct)
# Out:
# 2.070848447647918

# %%
df_clean['time'] = pd.to_datetime(df_clean['time'], format='%H:%M:%S').dt.time #it will become an object , later we can access month , hour , seconds as we want

# %%
df_clean['time'].dtype
# Out:
# dtype('O')

# %% [markdown]
# #### Dropping duplicados

# %%
df_clean.duplicated(subset=['userid', 'placeid', 'date', 'time']).sum() #A person can not be present at various places in the same time
# Out:
# np.int64(14438)

# %%
df_clean = df_clean.drop_duplicates(subset=['userid', 'placeid', 'date', 'time'])

# %%
df_clean.duplicated(subset=['userid', 'placeid', 'date', 'time']).sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### User ID correccion

# %%
df_clean['userid'].isna().sum()
# Out:
# np.int64(12928)

# %%
df_clean=df_clean.dropna(subset=['userid'])

# %%
df_clean['userid'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Sorting dataframe based on date and  time

# %%
df_clean=df_clean.sort_values(by=['userid','date','time'], ascending=[True,True,True])

# %% [markdown]
# #### Correccion de placeid

# %%
df_clean['placeid'].isna().sum()
# Out:
# np.int64(64452)

# %%
df_clean=df_clean.dropna(subset=['placeid'])

# %%
df_clean['placeid'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Correccion de Latitude y Longitude

# %%
df_clean[['lat','lon']].isna().sum()
# Out:
# lat    112280
# lon     69439
# dtype: int64

# %%
df_clean['lat']= df_clean.groupby('placeid')['lat'].transform(lambda x: x.fillna(method='ffill').fillna(method='bfill')) #filling the missing lat values with the same values of placeid.
# Out:
# C:\Users\ELCORTEINGLES\AppData\Local\Temp\ipykernel_13108\2723037462.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_clean['lat']= df_clean.groupby('placeid')['lat'].transform(lambda x: x.fillna(method='ffill').fillna(method='bfill')) #filling the missing lat values with the same values of placeid.

# %%
df_clean['lon']= df_clean.groupby('placeid')['lon'].transform(lambda x: x.fillna(method='ffill').fillna(method='bfill')) #NA
# Out:
# C:\Users\ELCORTEINGLES\AppData\Local\Temp\ipykernel_13108\1483064232.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_clean['lon']= df_clean.groupby('placeid')['lon'].transform(lambda x: x.fillna(method='ffill').fillna(method='bfill')) #NA

# %%
df_clean[['lat','lon']].isna().sum()
# Out:
# lat    11868
# lon     7142
# dtype: int64

# %%
df_clean= df_clean.dropna(subset=['lat','lon'])

# %%
df_clean[['lat','lon']].isna().sum()
# Out:
# lat    0
# lon    0
# dtype: int64

# %% [markdown]
# #### Lat , Lon ranges

# %%
print("Latitude:")
print("Min:", df_clean['lat'].min())
print("Max:", df_clean['lat'].max())

print("\nLongitude:")
print("Min:", df_clean['lon'].min())
print("Max:", df_clean['lon'].max())
# Out:
# Latitude:
# Min: -79.8202427478
# Max: 69.6802326
#
# Longitude:
# Min: -160.971636772
# Max: 177.98569

# %% [markdown]
# #### Correccion de city

# %%
df_clean['city'].isna().sum()
# Out:
# np.int64(185894)

# %%
df_clean= df_clean.dropna(subset=['city'])

# %%
df_clean['city'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Correccion de categories

# %%
df_clean['category'].isna().sum()
# Out:
# np.int64(251142)

# %%
df_clean['category'] = (
    df_clean.groupby('placeid')['category']
    .transform(lambda x: x.fillna(method='ffill').fillna(method='bfill'))
)
# Out:
# C:\Users\ELCORTEINGLES\AppData\Local\Temp\ipykernel_13108\1877764260.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   .transform(lambda x: x.fillna(method='ffill').fillna(method='bfill'))
# C:\Users\ELCORTEINGLES\AppData\Local\Temp\ipykernel_13108\1877764260.py:3: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .transform(lambda x: x.fillna(method='ffill').fillna(method='bfill'))

# %%
df_clean['category'].isna().sum()/len(df_clean)*100
# Out:
# np.float64(5.162577746016558)

# %%
df_clean['category'].nunique()
# Out:
# 685

# %% [markdown]
# ##### Reseting index

# %%
df_clean.head() #Before reset
# Out:
#        userid           placeid        lat         lon  city  \
# 680358     26  shimotakaido-sta  35.666150  139.641375  世田谷区
# 155543     26  shimotakaido-sta  35.666150  139.641375  世田谷区
# 155702     26                jr  35.690346  139.699788   新宿区
# 954686     26      shinjuku-sta  35.691635  139.700732   新宿区
# 714725     26           bookoff  35.661088  139.697353   渋谷区
#
#                            category       date      time
# 680358   Travel:Train Station:Train 2010-01-22  06:33:02
# 155543   Travel:Train Station:Train 2010-01-22  06:39:04
# 155702         Travel:Train Station 2010-01-22  06:39:04
# 954686  Travel Spots:Train Stations 2010-01-22  06:53:48
# 714725              Shops:Bookstore 2010-01-22  09:23:42

# %%
df_clean = df_clean.reset_index(drop=True)

# %%
df_clean.head() #After reset
# Out:
#   userid           placeid        lat         lon  city  \
# 0     26  shimotakaido-sta  35.666150  139.641375  世田谷区
# 1     26  shimotakaido-sta  35.666150  139.641375  世田谷区
# 2     26                jr  35.690346  139.699788   新宿区
# 3     26      shinjuku-sta  35.691635  139.700732   新宿区
# 4     26           bookoff  35.661088  139.697353   渋谷区
#
#                       category       date      time
# 0   Travel:Train Station:Train 2010-01-22  06:33:02
# 1   Travel:Train Station:Train 2010-01-22  06:39:04
# 2         Travel:Train Station 2010-01-22  06:39:04
# 3  Travel Spots:Train Stations 2010-01-22  06:53:48
# 4              Shops:Bookstore 2010-01-22  09:23:42

# %%
df_clean.to_csv('Clean-EDA-Evolve.csv', index=False)

# %% [markdown]
# # 3.4 Visualizaciones básicas

# %%
df1=pd.read_csv('Clean-EDA-Evolve.csv')
df1.head()
# Out:
#   userid           placeid        lat         lon  city  \
# 0     26  shimotakaido-sta  35.666150  139.641375  世田谷区
# 1     26  shimotakaido-sta  35.666150  139.641375  世田谷区
# 2     26                jr  35.690346  139.699788   新宿区
# 3     26      shinjuku-sta  35.691635  139.700732   新宿区
# 4     26           bookoff  35.661088  139.697353   渋谷区
#
#                       category        date      time
# 0   Travel:Train Station:Train  2010-01-22  06:33:02
# 1   Travel:Train Station:Train  2010-01-22  06:39:04
# 2         Travel:Train Station  2010-01-22  06:39:04
# 3  Travel Spots:Train Stations  2010-01-22  06:53:48
# 4              Shops:Bookstore  2010-01-22  09:23:42

# %% [markdown]
# #### Visualizacion Basico

# %%
plt.figure(figsize=(12,6))
city_counts = df1['city'].value_counts().head(10)
sns.barplot(x=city_counts.index, y=city_counts.values)
plt.xticks(rotation=45)
plt.title('Top 10 Cities by Check-ins')
plt.show()

# %%
plt.figure(figsize=(16,6))  # wider figure
sns.barplot(x=category_counts.index, y=category_counts.values)
plt.xticks(rotation=45, ha='right')  # rotate and align labels
plt.title('Top 10 POI Categories')
plt.show()

# %% [markdown]
# #### Temporal Visualizacion

# %%
daily_counts = df1.groupby('date').size()
plt.figure(figsize=(12,6))
daily_counts.plot()
plt.title('Daily Check-ins Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Check-ins')
plt.show()

# %% [markdown]
# #### Visualizacion Spatial

# %% [markdown]
# ##### Scatter plot

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='lon', y='lat', data=df1,  s=5, alpha=0.3)
plt.title('Global distribution of POI Locations by Category')
plt.show()

# %% [markdown]
# #### For better visualization of POI location

# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature

plt.figure(figsize=(13,8))
ax = plt.axes(projection=ccrs.PlateCarree())

ax.add_feature(cfeature.LAND, facecolor='lightgray')
ax.add_feature(cfeature.OCEAN, facecolor='lightblue')
ax.add_feature(cfeature.BORDERS, edgecolor='black')
ax.add_feature(cfeature.COASTLINE)


sns.scatterplot(x='lon', y='lat', data=df1, s=10, alpha=0.5, hue='category', legend=False)

plt.title("POI Locations Around the World")
plt.show()

# %%
top_cities = df1['city'].value_counts().head(5).index
df_top = df1[df1['city'].isin(top_cities)]
plt.figure(figsize=(12,6))
sns.countplot(data=df_top, x='city')
plt.title('POI Categories in Top 5 Cities')
plt.xticks(rotation=45)
plt.show()

# %%
user_counts = df1['userid'].value_counts()
plt.figure(figsize=(10,6))
plt.hist(user_counts, bins=30, color='lightgreen', edgecolor='black')
plt.xlabel('Number of Check-ins')
plt.ylabel('Number of Users')
plt.title('Distribution of Check-ins per User')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.hist(df1['lat'], bins=50, color='purple', edgecolor='black')
plt.xlabel('Latitude')
plt.ylabel('Number of POIs')
plt.title('Latitude Distribution of POIs')
plt.show()

# %% [markdown]
# # 3.5 Conclusiones exploratorias
#
#
# #### ✔️ Resumen general del dataset
# - El dataset contiene información de usuarios, lugares visitados (POIs), coordenadas geográficas, ciudad y marcas temporales.
# - Las columnas principales incluyen: `userid`, `placeid`, `datetime`, `latitude`, `longitude`, `city` y `category`.
# - El número total de registros es significativo para realizar análisis espaciales, temporales y de comportamiento del usuario.
#
# #### ✔️ Principales hallazgos
# Valores nulos:
# Algunos porcentajes altos de nulos en el dataset original:
# category: ~38%
# city: ~22%
# datetime: ~19%
# lat: ~13%
# lon: ~8%
#
# Después de la limpieza e imputación, los nulos se redujeron significativamente (ej. category ~5%).
#
# Duplicados:
# Se detectaron 27,784 filas duplicadas inicialmente.
# Eliminación de duplicados basada en (userid, placeid, date, time) asegura integridad temporal y espacial.
#
# Formato de fechas y horas:
# La columna datetime contenía registros corruptos y mal formateados.
# Se separó en date y time, y se imputaron valores faltantes con forward-fill por usuario.
#
# Coordenadas geográficas:
# Latitud y longitud tenían valores fuera de rango, que fueron corregidos o eliminados.
# Imputación de valores faltantes por placeid.
# Rango final válido de lat/lon asegura análisis espacial confiable.
#
# Distribuciones y patrones:
# Algunos usuarios realizaron muchos más check-ins que otros.
# Ciudades principales (p. ej., New York) dominan el dataset.
# Categorías de POIs desbalanceadas, reflejando patrones naturales de comportamiento de los usuarios.
# Se observaron patrones diarios y estacionales en los check-ins.
# Scatter plots muestran concentración de POIs en áreas urbanas principales.
#
# #### ✔️ Cambios aplicados durante la limpieza.
#
# Datetime:
# Conversión a datetime64[ns] y separación en date y time.
# Imputación de nulos mediante forward-fill por usuario.
#
# Duplicados:
# Eliminación de duplicados exactos según (userid, placeid, date, time).
#
# Usuarios y lugares:
# Eliminación de filas con userid o placeid faltantes.
#
# Latitud y longitud:
# Imputación de valores faltantes según placeid.
# Eliminación de registros con lat/lon nulos restantes.
#
# Ciudad y categoría:
# Imputación de nulos por placeid (forward-fill y backward-fill).
# Eliminación de nulos restantes y corrección de inconsistencias.
#
# Ordenamiento y reindexado:
# Ordenamiento por userid, date y time.
# Reset de índice para consistencia.
#
# Preparación para análisis
#
# Dataset limpio y listo para visualización, análisis exploratorio o modelado predictivo, como la recomendación del siguiente POI. Falta realizar el encoding de userid y placeid, aunque este puede variar según el modelo de IA que se utilice.
